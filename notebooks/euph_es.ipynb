# %% [markdown]
# There's a strange pyarrow dependency workaround that makes this only usable on CUDA gpus with the extra index pip install below

# %%
# !pip install scikit-learn tensorflow pandas datasets peft evaluate accelerate>=0.20.1 --extra-index-url=https://pypi.nvidia.com cudf-cu11
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-metadata 1.14.0 requires protobuf<4.21,>=3.20.3, but you have protobuf 4.23.4 which is incompatible.

# %%
#Restarts kernel without restarting runtime (I think)

# condacolab KERNEL RESTART \
# print("Restarting of kernel...") \
# get_ipython().kernel.do_shutdown(True)

# %%
# Import necessary libraries
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import f1_score, classification_report
from sklearn.utils import compute_class_weight
from transformers import AutoTokenizer, AutoModelForSequenceClassification, Trainer
import tensorflow as tf
import pandas as pd
import numpy as np

# %% [markdown]
# Skip Past this to get to Fine-Tuning Section

# %%
## Mount drive where training files are

##from google.colab import drive
##drive.mount('/content/drive/')

# %%
df = pd.read_csv('/content/drive/MyDrive/ES_train.csv')

# %%
df
# Out:
#       Unnamed: 0                                               text  label  \
# 0              0  Llamó la esposa hecha una furia porque lo esta...      1
# 1              1  Pero, a diferencia del medicamento que saltó a...      1
# 2              2  los bombardeos sobre Afganistán. Victoria Clar...      1
# 3              3  no existe allá la posibilidad del voto directo...      1
# 4              4  Acaso las limitaciones señaladas —entre las cu...      1
# ...          ...                                                ...    ...
# 1856        1856  Tuve entonces un sueño rarísimo. Soñé que esta...      0
# 1857        1857  Lo que todo el mundo esperaba era un fichaje d...      0
# 1858        1858  Poetas árabes de lengua francesa, y algunas de...      0
# 1859        1859  Pedro: ¿Para qué estoy en esto? No tiene senti...      0
# 1860        1860  Todos los saxofones son aptos para tocar [PET_...      0
#
#                     PET
# 0     Daños colaterales
# 1     Daños colaterales
# 2     Daños colaterales
# 3     Daños colaterales
# 4     Daños colaterales
# ...                 ...
# 1856             Partes
# 1857             Partes
# 1858             Partes
# 1859             Partes
# 1860             Partes
#
# [1861 rows x 4 columns]

# %%
##### First try manipulating data to get a feel for it


# # Split the data into training and testing sets
# X_train, X_test, y_train, y_test = train_test_split(df['text'], df['label'], test_size=0.2)

# # Initialize the feature extractor
# vectorizer = CountVectorizer()

# # Fit the feature extractor to the training data
# X_train_counts = vectorizer.fit_transform(X_train)

# #weights = compute_class_weight('balanced', np.unique(y), y)


# # Fit the model to the training data
# clf = MLPClassifier(solver='sgd', alpha=1e-5, learning_rate='adaptive', hidden_layer_sizes=(100,), random_state=42)
# clf.fit(X_train_counts, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPClassifier(alpha=1e-05, learning_rate='adaptive', random_state=42,
#               solver='sgd')

# %%
# Evaluate the model on the testing data
# y_pred = clf.predict(vectorizer.transform(X_test))
# score = f1_score(y_test, y_pred, average='macro')
# classification_report_mlp = classification_report(y_test, y_pred)

# print('Macro F1 score:', score)
# print('\nClassification Report:\n', classification_report_mlp)
# Out:
# Macro F1 score: 0.4931597835984788
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.52      0.11      0.18       122
#            1       0.70      0.96      0.81       269
#
#     accuracy                           0.69       391
#    macro avg       0.61      0.53      0.49       391
# weighted avg       0.65      0.69      0.61       391

# %%
# for index, row in df.iterrows():
#     new_text = ' '.join([str(word) for word in row['text']])
#     preprocessed_text = vectorizer.transform([new_text])[0]
#     predicted_label = clf.predict(preprocessed_text)
#     df.at[index, 'predicted_label'] = predicted_label

# %%
#df

# %%
#df['predicted_label'].unique()

# %%
#### Method actually used in paper description is below

# %% [markdown]
# Trying with Fine-Tuning Instead (Ensure that it's a new runtime to not have naming errors)

# %%
from datasets import load_dataset, DatasetDict, Dataset

from transformers import (
    AutoTokenizer,
    AutoConfig,
    AutoModelForSequenceClassification,
    DataCollatorWithPadding,
    TrainingArguments,
    Trainer)

from peft import PeftModel, PeftConfig, get_peft_model, LoraConfig
import evaluate
import torch
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive/')

# %%
df = pd.read_csv('/content/drive/MyDrive/ES_train.csv', usecols=['label', 'text'])

# %%
df
# Out:
#                                                    text  label
# 0     Llamó la esposa hecha una furia porque lo esta...      1
# 1     Pero, a diferencia del medicamento que saltó a...      1
# 2     los bombardeos sobre Afganistán. Victoria Clar...      1
# 3     no existe allá la posibilidad del voto directo...      1
# 4     Acaso las limitaciones señaladas —entre las cu...      1
# ...                                                 ...    ...
# 1856  Tuve entonces un sueño rarísimo. Soñé que esta...      0
# 1857  Lo que todo el mundo esperaba era un fichaje d...      0
# 1858  Poetas árabes de lengua francesa, y algunas de...      0
# 1859  Pedro: ¿Para qué estoy en esto? No tiene senti...      0
# 1860  Todos los saxofones son aptos para tocar [PET_...      0
#
# [1861 rows x 2 columns]

# %%
df['label'].value_counts()
# Out:
# 1    1143
# 0     718
# Name: label, dtype: int64

# %%
##Converting Dataframe to Dataset for HF models

import datasets
from datasets import Dataset

ds = Dataset.from_pandas(df)

## To split up dataset, shuffled by default
ds = ds.train_test_split(test_size=0.2)

# %%
ds
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'label'],
#         num_rows: 1488
#     })
#     test: Dataset({
#         features: ['text', 'label'],
#         num_rows: 373
#     })
# })

# %%
model_checkpoint = 'FacebookAI/xlm-roberta-large'

# define label maps
id2label = {0: "Non-Euphemistic", 1: "Euphemistic"}
label2id = {"Non-Euphemistic":0, "Euphemistic":1}

# generate classification model from model_checkpoint
model = AutoModelForSequenceClassification.from_pretrained(
    model_checkpoint, num_labels=2, id2label=id2label, label2id=label2id)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/616 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.24G [00:00<?, ?B/s]
# Some weights of XLMRobertaForSequenceClassification were not initialized from the model checkpoint at FacebookAI/xlm-roberta-large and are newly initialized: ['classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.dense.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
model
# Out:
# XLMRobertaForSequenceClassification(
#   (roberta): XLMRobertaModel(
#     (embeddings): XLMRobertaEmbeddings(
#       (word_embeddings): Embedding(250002, 1024, padding_idx=1)
#       (position_embeddings): Embedding(514, 1024, padding_idx=1)
#       (token_type_embeddings): Embedding(1, 1024)
#       (LayerNorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): XLMRobertaEncoder(
#       (layer): ModuleList(
#         (0-23): 24 x XLMRobertaLayer(
#           (attention): XLMRobertaAttention(
#             (self): XLMRobertaSelfAttention(
#               (query): Linear(in_features=1024, out_features=1024, bias=True)
#               (key): Linear(in_features=1024, out_features=1024, bias=True)
#               (value): Linear(in_features=1024, out_features=1024, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): XLMRobertaSelfOutput(
#               (dense): Linear(in_features=1024, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): XLMRobertaIntermediate(
#             (dense): Linear(in_features=1024, out_features=4096, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): XLMRobertaOutput(
#             (dense): Linear(in_features=4096, out_features=1024, bias=True)
#             (LayerNorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#   )
#   (classifier): XLMRobertaClassificationHead(
#     (dense): Linear(in_features=1024, out_features=1024, bias=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#     (out_proj): Linear(in_features=1024, out_features=2, bias=True)
#   )
# )

# %%
# create tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_checkpoint, add_prefix_space=True)

# add pad token if none exists
if tokenizer.pad_token is None:
    tokenizer.add_special_tokens({'pad_token': '[PAD]'})
    model.resize_token_embeddings(len(tokenizer))
# Out:
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.10M [00:00<?, ?B/s]

# %%
# create tokenize function
def tokenize_function(examples):
    # extract text
    text = examples["text"]

    #tokenize and truncate text
    tokenizer.truncation_side = "left"
    tokenized_inputs = tokenizer(
        text,
        return_tensors="np",
        truncation=True,
        max_length=512
    )

    return tokenized_inputs

# %%
# tokenize training and validation datasets
tokenized_dataset = ds.map(tokenize_function, batched=True)
tokenized_dataset
# Out:
# Map:   0%|          | 0/1488 [00:00<?, ? examples/s]
# Map:   0%|          | 0/373 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'label', 'input_ids', 'attention_mask'],
#         num_rows: 1488
#     })
#     test: Dataset({
#         features: ['text', 'label', 'input_ids', 'attention_mask'],
#         num_rows: 373
#     })
# })

# %%
# create data collator
data_collator = DataCollatorWithPadding(tokenizer=tokenizer)

# %%
# define an evaluation function to pass into trainer later

def compute_metrics(p):

    f1_metric = evaluate.load("glue", "mrpc")
    precision_metric = evaluate.load("precision")
    recall_metric = evaluate.load("recall")

    predictions, labels = p
    predictions = np.argmax(predictions, axis=-1)

    precision = precision_metric.compute(predictions=predictions, references=labels)["precision"]
    recall = recall_metric.compute(predictions=predictions, references=labels)["recall"]
    f1_metric = f1_metric.compute(predictions=predictions, references=labels)

    return {"precision": precision, "recall": recall,  "F1 and Accuracy": f1_metric}

# %%
# define list of examples
# text_list = ["He was fired yesterday", "She passed gas", "I was between jobs"]

# print("Untrained model predictions:")
# print("----------------------------")
# for text in text_list:
#     # tokenize text
#     inputs = tokenizer.encode(text, return_tensors="pt")
#     # compute logits
#     logits = model(inputs).logits
#     # convert logits to label
#     predictions = torch.argmax(logits)

#     print(text + " - " + id2label[predictions.tolist()])

# %%
peft_config = LoraConfig(task_type="SEQ_CLS",
                        r=4,
                        lora_alpha=32,
                        lora_dropout=0.01,
                         target_modules = ['value'])

# %%
peft_config
# Out:
# LoraConfig(peft_type=<PeftType.LORA: 'LORA'>, auto_mapping=None, base_model_name_or_path=None, revision=None, task_type='SEQ_CLS', inference_mode=False, r=4, target_modules={'value'}, lora_alpha=32, lora_dropout=0.01, fan_in_fan_out=False, bias='none', use_rslora=False, modules_to_save=None, init_lora_weights=True, layers_to_transform=None, layers_pattern=None, rank_pattern={}, alpha_pattern={}, megatron_config=None, megatron_core='megatron.core', loftq_config={})

# %%
model = get_peft_model(model, peft_config)
model.print_trainable_parameters()
# Out:
# trainable params: 1,248,258 || all params: 561,140,740 || trainable%: 0.22245007553719945

# %%
# hyperparameters
lr = 1e-5
batch_size = 4
num_epochs = 10

# %%
# define training arguments
training_args = TrainingArguments(
    output_dir= model_checkpoint + "-lora-text-classification",
    learning_rate=lr,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    num_train_epochs=num_epochs,
    weight_decay=0.01,
    evaluation_strategy="epoch",
    save_strategy="epoch",
    load_best_model_at_end=True,
)

# %%
# creater trainer object
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset["train"],
    eval_dataset=tokenized_dataset["test"],
    tokenizer=tokenizer,
    data_collator=data_collator, # this will dynamically pad examples in each batch to be equal length
    compute_metrics=compute_metrics,
)

# train model
trainer.train()
# Out:
# You're using a XLMRobertaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='3720' max='3720' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3720/3720 20:15, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1 and accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.655257</td>
#       <td>0.638070</td>
#       <td>1.000000</td>
#       <td>{'accuracy': 0.6380697050938338, 'f1': 0.779050736497545}</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.675800</td>
#       <td>0.653360</td>
#       <td>0.638070</td>
#       <td>1.000000</td>
#       <td>{'accuracy': 0.6380697050938338, 'f1': 0.779050736497545}</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.676500</td>
#       <td>0.651784</td>
#       <td>0.638070</td>
#       <td>1.000000</td>
#       <td>{'accuracy': 0.6380697050938338, 'f1': 0.779050736497545}</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.676500</td>
#       <td>0.651949</td>
#       <td>0.638070</td>
#       <td>1.000000</td>
#       <td>{'accuracy': 0.6380697050938338, 'f1': 0.779050736497545}</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.672200</td>
#       <td>0.647045</td>
#       <td>0.638070</td>
#       <td>1.000000</td>
#       <td>{'accuracy': 0.6380697050938338, 'f1': 0.779050736497545}</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.665400</td>
#       <td>0.642542</td>
#       <td>0.638070</td>
#       <td>1.000000</td>
#       <td>{'accuracy': 0.6380697050938338, 'f1': 0.779050736497545}</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.662600</td>
#       <td>0.641883</td>
#       <td>0.638070</td>
#       <td>1.000000</td>
#       <td>{'accuracy': 0.6380697050938338, 'f1': 0.779050736497545}</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.662600</td>
#       <td>0.640365</td>
#       <td>0.637097</td>
#       <td>0.995798</td>
#       <td>{'accuracy': 0.6353887399463807, 'f1': 0.7770491803278688}</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.654700</td>
#       <td>0.635600</td>
#       <td>0.638070</td>
#       <td>1.000000</td>
#       <td>{'accuracy': 0.6380697050938338, 'f1': 0.779050736497545}</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.654400</td>
#       <td>0.634327</td>
#       <td>0.637097</td>
#       <td>0.995798</td>
#       <td>{'accuracy': 0.6353887399463807, 'f1': 0.7770491803278688}</td>
#     </tr>
#   </tbody>
# </table><p>
# Downloading builder script:   0%|          | 0.00/5.75k [00:00<?, ?B/s]
# Downloading builder script:   0%|          | 0.00/7.55k [00:00<?, ?B/s]
# Downloading builder script:   0%|          | 0.00/7.36k [00:00<?, ?B/s]
# Trainer is attempting to log a value of "{'accuracy': 0.6380697050938338, 'f1': 0.779050736497545}" of type <class 'dict'> for key "eval/F1 and Accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.6380697050938338, 'f1': 0.779050736497545}" of type <class 'dict'> for key "eval/F1 and Accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.6380697050938338, 'f1': 0.779050736497545}" of type <class 'dict'> for key "eval/F1 and Accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.6380697050938338, 'f1': 0.779050736497545}" of type <class 'dict'> for key "eval/F1 and Accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.6380697050938338, 'f1': 0.779050736497545}" of type <class 'dict'> for key "eval/F1 and Accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.6380697050938338, 'f1': 0.779050736497545}" of type <class 'dict'> for key "eval/F1 and Accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.6380697050938338, 'f1': 0.779050736497545}" of type <class 'dict'> for key "eval/F1 and Accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.6353887399463807, 'f1': 0.7770491803278688}" of type <class 'dict'> for key "eval/F1 and Accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.6380697050938338, 'f1': 0.779050736497545}" of type <class 'dict'> for key "eval/F1 and Accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.6353887399463807, 'f1': 0.7770491803278688}" of type <class 'dict'> for key "eval/F1 and Accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# TrainOutput(global_step=3720, training_loss=0.6647343010030767, metrics={'train_runtime': 1217.9532, 'train_samples_per_second': 12.217, 'train_steps_per_second': 3.054, 'total_flos': 4402201542922848.0, 'train_loss': 0.6647343010030767, 'epoch': 10.0})

# %%
model.to('cuda')

print("Trained model predictions:")
print("--------------------------")


testing_df = pd.read_csv('/content/drive/MyDrive/ES_train.csv')


for idx, row in testing_df.iterrows():
    # Get the text from the row
    text = row["text"]

    inputs = tokenizer.encode(text, return_tensors="pt").to("cuda")

    logits = model(inputs).logits
    predictions = torch.max(logits,1).indices

    print(f"{idx} -- {id2label[predictions.tolist()[0]]}")
# Out:
# Trained model predictions:
# --------------------------
# 0 -- Euphemistic
# 1 -- Euphemistic
# 2 -- Euphemistic
# 3 -- Euphemistic
# 4 -- Euphemistic
# 5 -- Euphemistic
# 6 -- Euphemistic
# 7 -- Euphemistic
# 8 -- Euphemistic
# 9 -- Euphemistic
# 10 -- Euphemistic
# 11 -- Euphemistic
# 12 -- Euphemistic
# 13 -- Euphemistic
# 14 -- Euphemistic
# 15 -- Euphemistic
# 16 -- Euphemistic
# 17 -- Euphemistic
# 18 -- Euphemistic
# 19 -- Euphemistic
# 20 -- Euphemistic
# 21 -- Euphemistic
# 22 -- Euphemistic
# 23 -- Euphemistic
# 24 -- Euphemistic
# 25 -- Euphemistic
# 26 -- Euphemistic
# 27 -- Euphemistic
# 28 -- Euphemistic
# 29 -- Euphemistic
# 30 -- Euphemistic
# 31 -- Euphemistic
# 32 -- Euphemistic
# 33 -- Euphemistic
# 34 -- Euphemistic
# 35 -- Euphemistic
# 36 -- Euphemistic
# 37 -- Euphemistic
# 38 -- Euphemistic
# 39 -- Euphemistic
# 40 -- Euphemistic
# 41 -- Euphemistic
# 42 -- Euphemistic
# 43 -- Euphemistic
# 44 -- Euphemistic
# 45 -- Euphemistic
# 46 -- Euphemistic
# 47 -- Euphemistic
# 48 -- Euphemistic
# 49 -- Euphemistic
# 50 -- Euphemistic
# 51 -- Euphemistic
# 52 -- Euphemistic
# 53 -- Euphemistic
# 54 -- Euphemistic
# 55 -- Euphemistic
# 56 -- Euphemistic
# 57 -- Euphemistic
# 58 -- Euphemistic
# 59 -- Euphemistic
# 60 -- Euphemistic
# 61 -- Euphemistic
# 62 -- Euphemistic
# 63 -- Euphemistic
# 64 -- Euphemistic
# 65 -- Euphemistic
# 66 -- Euphemistic
# 67 -- Euphemistic
# 68 -- Euphemistic
# 69 -- Euphemistic
# 70 -- Euphemistic
# 71 -- Euphemistic
# 72 -- Euphemistic
# 73 -- Euphemistic
# 74 -- Euphemistic
# 75 -- Euphemistic
# 76 -- Euphemistic
# 77 -- Euphemistic
# 78 -- Euphemistic
# 79 -- Euphemistic
# 80 -- Euphemistic
# 81 -- Euphemistic
# 82 -- Euphemistic
# 83 -- Euphemistic
# 84 -- Euphemistic
# 85 -- Euphemistic
# 86 -- Euphemistic
# 87 -- Euphemistic
# 88 -- Euphemistic
# 89 -- Euphemistic
# 90 -- Euphemistic
# 91 -- Euphemistic
# 92 -- Euphemistic
# 93 -- Euphemistic
# 94 -- Euphemistic
# 95 -- Euphemistic
# 96 -- Euphemistic
# 97 -- Euphemistic
# 98 -- Euphemistic
# 99 -- Euphemistic
# 100 -- Euphemistic
# 101 -- Euphemistic
# 102 -- Euphemistic
# 103 -- Euphemistic
# 104 -- Euphemistic
# 105 -- Euphemistic
# 106 -- Euphemistic
# 107 -- Euphemistic
# 108 -- Euphemistic
# 109 -- Euphemistic
# 110 -- Euphemistic
# 111 -- Euphemistic
# 112 -- Euphemistic
# 113 -- Euphemistic
# 114 -- Euphemistic
# 115 -- Euphemistic
# 116 -- Euphemistic
# 117 -- Euphemistic
# 118 -- Euphemistic
# 119 -- Euphemistic
# 120 -- Euphemistic
# 121 -- Euphemistic
# 122 -- Euphemistic
# 123 -- Euphemistic
# 124 -- Euphemistic
# 125 -- Euphemistic
# 126 -- Euphemistic
# 127 -- Euphemistic
# 128 -- Euphemistic
# 129 -- Euphemistic
# 130 -- Euphemistic
# 131 -- Euphemistic
# 132 -- Euphemistic
# 133 -- Euphemistic
# 134 -- Euphemistic
# 135 -- Euphemistic
# 136 -- Euphemistic
# 137 -- Euphemistic
# 138 -- Euphemistic
# 139 -- Euphemistic
# 140 -- Euphemistic
# 141 -- Euphemistic
# 142 -- Euphemistic
# 143 -- Euphemistic
# 144 -- Euphemistic
# 145 -- Euphemistic
# 146 -- Euphemistic
# 147 -- Euphemistic
# 148 -- Euphemistic
# 149 -- Euphemistic
# 150 -- Euphemistic
# 151 -- Euphemistic
# 152 -- Euphemistic
# 153 -- Euphemistic
# 154 -- Euphemistic
# 155 -- Euphemistic
# 156 -- Euphemistic
# 157 -- Euphemistic
# 158 -- Euphemistic
# 159 -- Euphemistic
# 160 -- Euphemistic
# 161 -- Euphemistic
# 162 -- Euphemistic
# 163 -- Euphemistic
# 164 -- Euphemistic
# 165 -- Euphemistic
# 166 -- Euphemistic
# 167 -- Euphemistic
# 168 -- Euphemistic
# 169 -- Euphemistic
# 170 -- Euphemistic
# 171 -- Euphemistic
# 172 -- Euphemistic
# 173 -- Euphemistic
# 174 -- Euphemistic
# 175 -- Euphemistic
# 176 -- Euphemistic
# 177 -- Euphemistic
# 178 -- Euphemistic
# 179 -- Euphemistic
# 180 -- Euphemistic
# 181 -- Euphemistic
# 182 -- Euphemistic
# 183 -- Euphemistic
# 184 -- Euphemistic
# 185 -- Euphemistic
# 186 -- Euphemistic
# 187 -- Euphemistic
# 188 -- Euphemistic
# 189 -- Euphemistic
# 190 -- Euphemistic
# 191 -- Euphemistic
# 192 -- Euphemistic
# 193 -- Euphemistic
# 194 -- Euphemistic
# 195 -- Euphemistic
# 196 -- Euphemistic
# 197 -- Euphemistic
# 198 -- Euphemistic
# 199 -- Euphemistic
# 200 -- Euphemistic
# 201 -- Euphemistic
# 202 -- Euphemistic
# 203 -- Euphemistic
# 204 -- Euphemistic
# 205 -- Euphemistic
# 206 -- Euphemistic
# 207 -- Euphemistic
# 208 -- Euphemistic
# 209 -- Euphemistic
# 210 -- Euphemistic
# 211 -- Euphemistic
# 212 -- Euphemistic
# 213 -- Euphemistic
# 214 -- Euphemistic
# 215 -- Euphemistic
# 216 -- Euphemistic
# 217 -- Euphemistic
# 218 -- Euphemistic
# 219 -- Euphemistic
# 220 -- Euphemistic
# 221 -- Euphemistic
# 222 -- Euphemistic
# 223 -- Euphemistic
# 224 -- Euphemistic
# 225 -- Euphemistic
# 226 -- Euphemistic
# 227 -- Euphemistic
# 228 -- Euphemistic
# 229 -- Euphemistic
# 230 -- Euphemistic
# 231 -- Euphemistic
# 232 -- Euphemistic
# 233 -- Euphemistic
# 234 -- Euphemistic
# 235 -- Euphemistic
# 236 -- Euphemistic
# 237 -- Euphemistic
# 238 -- Euphemistic
# 239 -- Euphemistic
# 240 -- Euphemistic
# 241 -- Euphemistic
# 242 -- Euphemistic
# 243 -- Euphemistic
# 244 -- Euphemistic
# 245 -- Euphemistic
# 246 -- Euphemistic
# 247 -- Euphemistic
# 248 -- Euphemistic
# 249 -- Euphemistic
# 250 -- Euphemistic
# 251 -- Euphemistic
# 252 -- Euphemistic
# 253 -- Euphemistic
# 254 -- Euphemistic
# 255 -- Euphemistic
# 256 -- Euphemistic
# 257 -- Euphemistic
# 258 -- Euphemistic
# 259 -- Euphemistic
# 260 -- Euphemistic
# 261 -- Euphemistic
# 262 -- Euphemistic
# 263 -- Euphemistic
# 264 -- Euphemistic
# 265 -- Euphemistic
# 266 -- Euphemistic
# 267 -- Euphemistic
# 268 -- Euphemistic
# 269 -- Euphemistic
# 270 -- Euphemistic
# 271 -- Euphemistic
# 272 -- Euphemistic
# 273 -- Euphemistic
# 274 -- Euphemistic
# 275 -- Euphemistic
# 276 -- Euphemistic
# 277 -- Euphemistic
# 278 -- Euphemistic
# 279 -- Euphemistic
# 280 -- Euphemistic
# 281 -- Euphemistic
# 282 -- Euphemistic
# 283 -- Euphemistic
# 284 -- Euphemistic
# 285 -- Euphemistic
# 286 -- Euphemistic
# 287 -- Euphemistic
# 288 -- Euphemistic
# 289 -- Euphemistic
# 290 -- Euphemistic
# 291 -- Euphemistic
# 292 -- Euphemistic
# 293 -- Euphemistic
# 294 -- Euphemistic
# 295 -- Euphemistic
# 296 -- Euphemistic
# 297 -- Euphemistic
# 298 -- Euphemistic
# 299 -- Euphemistic
# 300 -- Euphemistic
# 301 -- Euphemistic
# 302 -- Euphemistic
# 303 -- Euphemistic
# 304 -- Euphemistic
# 305 -- Euphemistic
# 306 -- Euphemistic
# 307 -- Euphemistic
# 308 -- Euphemistic
# 309 -- Euphemistic
# 310 -- Euphemistic
# 311 -- Euphemistic
# 312 -- Euphemistic
# 313 -- Euphemistic
# 314 -- Euphemistic
# 315 -- Euphemistic
# 316 -- Euphemistic
# 317 -- Euphemistic
# 318 -- Euphemistic
# 319 -- Euphemistic
# 320 -- Euphemistic
# 321 -- Euphemistic
# 322 -- Euphemistic
# 323 -- Euphemistic
# 324 -- Euphemistic
# 325 -- Euphemistic
# 326 -- Euphemistic
# 327 -- Euphemistic
# 328 -- Euphemistic
# 329 -- Euphemistic
# 330 -- Euphemistic
# 331 -- Euphemistic
# 332 -- Euphemistic
# 333 -- Euphemistic
# 334 -- Euphemistic
# 335 -- Euphemistic
# 336 -- Euphemistic
# 337 -- Euphemistic
# 338 -- Euphemistic
# 339 -- Euphemistic
# 340 -- Euphemistic
# 341 -- Euphemistic
# 342 -- Euphemistic
# 343 -- Euphemistic
# 344 -- Euphemistic
# 345 -- Euphemistic
# 346 -- Euphemistic
# 347 -- Euphemistic
# 348 -- Euphemistic
# 349 -- Euphemistic
# 350 -- Euphemistic
# 351 -- Euphemistic
# 352 -- Euphemistic
# 353 -- Euphemistic
# 354 -- Euphemistic
# 355 -- Euphemistic
# 356 -- Euphemistic
# 357 -- Euphemistic
# 358 -- Euphemistic
# 359 -- Euphemistic
# 360 -- Euphemistic
# 361 -- Euphemistic
# 362 -- Euphemistic
# 363 -- Euphemistic
# 364 -- Euphemistic
# 365 -- Euphemistic
# 366 -- Euphemistic
# 367 -- Euphemistic
# 368 -- Euphemistic
# 369 -- Euphemistic
# 370 -- Euphemistic
# 371 -- Euphemistic
# 372 -- Euphemistic
# 373 -- Euphemistic
# 374 -- Euphemistic
# 375 -- Euphemistic
# 376 -- Euphemistic
# 377 -- Euphemistic
# 378 -- Euphemistic
# 379 -- Euphemistic
# 380 -- Euphemistic
# 381 -- Euphemistic
# 382 -- Euphemistic
# 383 -- Euphemistic
# 384 -- Euphemistic
# 385 -- Euphemistic
# 386 -- Euphemistic
# 387 -- Euphemistic
# 388 -- Euphemistic
# 389 -- Euphemistic
# 390 -- Euphemistic
# 391 -- Euphemistic
# 392 -- Euphemistic
# 393 -- Euphemistic
# 394 -- Euphemistic
# 395 -- Euphemistic
# 396 -- Euphemistic
# 397 -- Euphemistic
# 398 -- Euphemistic
# 399 -- Euphemistic
# 400 -- Euphemistic
# 401 -- Euphemistic
# 402 -- Euphemistic
# 403 -- Euphemistic
# 404 -- Euphemistic
# 405 -- Euphemistic
# 406 -- Euphemistic
# 407 -- Euphemistic
# 408 -- Euphemistic
# 409 -- Euphemistic
# 410 -- Euphemistic
# 411 -- Euphemistic
# 412 -- Euphemistic
# 413 -- Euphemistic
# 414 -- Euphemistic
# 415 -- Euphemistic
# 416 -- Euphemistic
# 417 -- Euphemistic
# 418 -- Euphemistic
# 419 -- Euphemistic
# 420 -- Euphemistic
# 421 -- Euphemistic
# 422 -- Euphemistic
# 423 -- Euphemistic
# 424 -- Euphemistic
# 425 -- Euphemistic
# 426 -- Euphemistic
# 427 -- Euphemistic
# 428 -- Euphemistic
# 429 -- Euphemistic
# 430 -- Euphemistic
# 431 -- Euphemistic
# 432 -- Euphemistic
# 433 -- Euphemistic
# 434 -- Euphemistic
# 435 -- Euphemistic
# 436 -- Euphemistic
# 437 -- Euphemistic
# 438 -- Euphemistic
# 439 -- Euphemistic
# 440 -- Euphemistic
# 441 -- Euphemistic
# 442 -- Euphemistic
# 443 -- Euphemistic
# 444 -- Euphemistic
# 445 -- Euphemistic
# 446 -- Euphemistic
# 447 -- Euphemistic
# 448 -- Euphemistic
# 449 -- Euphemistic
# 450 -- Euphemistic
# 451 -- Euphemistic
# 452 -- Euphemistic
# 453 -- Euphemistic
# 454 -- Euphemistic
# 455 -- Euphemistic
# 456 -- Euphemistic
# 457 -- Euphemistic
# 458 -- Euphemistic
# 459 -- Euphemistic
# 460 -- Euphemistic
# 461 -- Euphemistic
# 462 -- Euphemistic
# 463 -- Euphemistic
# 464 -- Euphemistic
# 465 -- Euphemistic
# 466 -- Euphemistic
# 467 -- Euphemistic
# 468 -- Euphemistic
# 469 -- Euphemistic
# 470 -- Euphemistic
# 471 -- Euphemistic
# 472 -- Euphemistic
# 473 -- Euphemistic
# 474 -- Euphemistic
# 475 -- Euphemistic
# 476 -- Euphemistic
# 477 -- Euphemistic
# 478 -- Euphemistic
# 479 -- Euphemistic
# 480 -- Euphemistic
# 481 -- Euphemistic
# 482 -- Euphemistic
# 483 -- Euphemistic
# 484 -- Euphemistic
# 485 -- Euphemistic
# 486 -- Euphemistic
# 487 -- Euphemistic
# 488 -- Euphemistic
# 489 -- Euphemistic
# 490 -- Euphemistic
# 491 -- Euphemistic
# 492 -- Euphemistic
# 493 -- Euphemistic
# 494 -- Euphemistic
# 495 -- Euphemistic
# 496 -- Euphemistic
# 497 -- Euphemistic
# 498 -- Euphemistic
# 499 -- Euphemistic
# 500 -- Euphemistic
# 501 -- Euphemistic
# 502 -- Euphemistic
# 503 -- Euphemistic
# 504 -- Euphemistic
# 505 -- Euphemistic
# 506 -- Euphemistic
# 507 -- Euphemistic
# 508 -- Euphemistic
# 509 -- Euphemistic
# 510 -- Euphemistic
# 511 -- Euphemistic
# 512 -- Euphemistic
# 513 -- Euphemistic
# 514 -- Euphemistic
# 515 -- Euphemistic
# 516 -- Euphemistic
# 517 -- Euphemistic
# 518 -- Euphemistic
# 519 -- Euphemistic
# 520 -- Euphemistic
# 521 -- Euphemistic
# 522 -- Euphemistic
# 523 -- Euphemistic
# 524 -- Euphemistic
# 525 -- Euphemistic
# 526 -- Euphemistic
# 527 -- Euphemistic
# 528 -- Euphemistic
# 529 -- Euphemistic
# 530 -- Euphemistic
# 531 -- Euphemistic
# 532 -- Euphemistic
# 533 -- Euphemistic
# 534 -- Euphemistic
# 535 -- Euphemistic
# 536 -- Euphemistic
# 537 -- Euphemistic
# 538 -- Euphemistic
# 539 -- Euphemistic
# 540 -- Euphemistic
# 541 -- Euphemistic
# 542 -- Euphemistic
# 543 -- Euphemistic
# 544 -- Euphemistic
# 545 -- Euphemistic
# 546 -- Euphemistic
# 547 -- Euphemistic
# 548 -- Euphemistic
# 549 -- Euphemistic
# 550 -- Euphemistic
# 551 -- Euphemistic
# 552 -- Euphemistic
# 553 -- Euphemistic
# 554 -- Euphemistic
# 555 -- Euphemistic
# 556 -- Euphemistic
# 557 -- Euphemistic
# 558 -- Euphemistic
# 559 -- Euphemistic
# 560 -- Euphemistic
# 561 -- Euphemistic
# 562 -- Euphemistic
# 563 -- Euphemistic
# 564 -- Euphemistic
# 565 -- Euphemistic
# 566 -- Euphemistic
# 567 -- Euphemistic
# 568 -- Euphemistic
# 569 -- Euphemistic
# 570 -- Euphemistic
# 571 -- Euphemistic
# 572 -- Euphemistic
# 573 -- Euphemistic
# 574 -- Euphemistic
# 575 -- Euphemistic
# 576 -- Euphemistic
# 577 -- Euphemistic
# 578 -- Euphemistic
# 579 -- Euphemistic
# 580 -- Euphemistic
# 581 -- Euphemistic
# 582 -- Euphemistic
# 583 -- Euphemistic
# 584 -- Euphemistic
# 585 -- Euphemistic
# 586 -- Euphemistic
# 587 -- Euphemistic
# 588 -- Euphemistic
# 589 -- Euphemistic
# 590 -- Euphemistic
# 591 -- Euphemistic
# 592 -- Euphemistic
# 593 -- Euphemistic
# 594 -- Euphemistic
# 595 -- Euphemistic
# 596 -- Euphemistic
# 597 -- Non-Euphemistic
# 598 -- Euphemistic
# 599 -- Euphemistic
# 600 -- Euphemistic
# 601 -- Euphemistic
# 602 -- Euphemistic
# 603 -- Euphemistic
# 604 -- Euphemistic
# 605 -- Euphemistic
# 606 -- Euphemistic
# 607 -- Euphemistic
# 608 -- Euphemistic
# 609 -- Euphemistic
# 610 -- Euphemistic
# 611 -- Euphemistic
# 612 -- Euphemistic
# 613 -- Euphemistic
# 614 -- Euphemistic
# 615 -- Euphemistic
# 616 -- Euphemistic
# 617 -- Euphemistic
# 618 -- Euphemistic
# 619 -- Euphemistic
# 620 -- Euphemistic
# 621 -- Euphemistic
# 622 -- Euphemistic
# 623 -- Euphemistic
# 624 -- Euphemistic
# 625 -- Euphemistic
# 626 -- Euphemistic
# 627 -- Euphemistic
# 628 -- Euphemistic
# 629 -- Non-Euphemistic
# 630 -- Euphemistic
# 631 -- Euphemistic
# 632 -- Euphemistic
# 633 -- Euphemistic
# 634 -- Euphemistic
# 635 -- Euphemistic
# 636 -- Euphemistic
# 637 -- Euphemistic
# 638 -- Non-Euphemistic
# 639 -- Euphemistic
# 640 -- Euphemistic
# 641 -- Euphemistic
# 642 -- Euphemistic
# 643 -- Euphemistic
# 644 -- Euphemistic
# 645 -- Euphemistic
# 646 -- Euphemistic
# 647 -- Euphemistic
# 648 -- Euphemistic
# 649 -- Euphemistic
# 650 -- Euphemistic
# 651 -- Euphemistic
# 652 -- Euphemistic
# 653 -- Euphemistic
# 654 -- Euphemistic
# 655 -- Euphemistic
# 656 -- Euphemistic
# 657 -- Euphemistic
# 658 -- Euphemistic
# 659 -- Euphemistic
# 660 -- Euphemistic
# 661 -- Euphemistic
# 662 -- Euphemistic
# 663 -- Euphemistic
# 664 -- Euphemistic
# 665 -- Euphemistic
# 666 -- Euphemistic
# 667 -- Euphemistic
# 668 -- Euphemistic
# 669 -- Euphemistic
# 670 -- Euphemistic
# 671 -- Euphemistic
# 672 -- Euphemistic
# 673 -- Euphemistic
# 674 -- Euphemistic
# 675 -- Euphemistic
# 676 -- Euphemistic
# 677 -- Euphemistic
# 678 -- Euphemistic
# 679 -- Euphemistic
# 680 -- Euphemistic
# 681 -- Euphemistic
# 682 -- Euphemistic
# 683 -- Euphemistic
# 684 -- Euphemistic
# 685 -- Euphemistic
# 686 -- Euphemistic
# 687 -- Euphemistic
# 688 -- Euphemistic
# 689 -- Euphemistic
# 690 -- Euphemistic
# 691 -- Euphemistic
# 692 -- Euphemistic
# 693 -- Euphemistic
# 694 -- Euphemistic
# 695 -- Euphemistic
# 696 -- Euphemistic
# 697 -- Euphemistic
# 698 -- Euphemistic
# 699 -- Euphemistic
# 700 -- Euphemistic
# 701 -- Euphemistic
# 702 -- Euphemistic
# 703 -- Euphemistic
# 704 -- Euphemistic
# 705 -- Euphemistic
# 706 -- Euphemistic
# 707 -- Euphemistic
# 708 -- Euphemistic
# 709 -- Euphemistic
# 710 -- Euphemistic
# 711 -- Euphemistic
# 712 -- Euphemistic
# 713 -- Euphemistic
# 714 -- Euphemistic
# 715 -- Euphemistic
# 716 -- Euphemistic
# 717 -- Euphemistic
# 718 -- Euphemistic
# 719 -- Euphemistic
# 720 -- Euphemistic
# 721 -- Euphemistic
# 722 -- Euphemistic
# 723 -- Euphemistic
# 724 -- Euphemistic
# 725 -- Euphemistic
# 726 -- Euphemistic
# 727 -- Euphemistic
# 728 -- Euphemistic
# 729 -- Euphemistic
# 730 -- Euphemistic
# 731 -- Euphemistic
# 732 -- Euphemistic
# 733 -- Euphemistic
# 734 -- Euphemistic
# 735 -- Euphemistic
# 736 -- Euphemistic
# 737 -- Euphemistic
# 738 -- Euphemistic
# 739 -- Euphemistic
# 740 -- Euphemistic
# 741 -- Euphemistic
# 742 -- Euphemistic
# 743 -- Euphemistic
# 744 -- Euphemistic
# 745 -- Euphemistic
# 746 -- Euphemistic
# 747 -- Euphemistic
# 748 -- Euphemistic
# 749 -- Euphemistic
# 750 -- Euphemistic
# 751 -- Euphemistic
# 752 -- Euphemistic
# 753 -- Euphemistic
# 754 -- Euphemistic
# 755 -- Euphemistic
# 756 -- Euphemistic
# 757 -- Euphemistic
# 758 -- Euphemistic
# 759 -- Euphemistic
# 760 -- Euphemistic
# 761 -- Euphemistic
# 762 -- Euphemistic
# 763 -- Euphemistic
# 764 -- Euphemistic
# 765 -- Euphemistic
# 766 -- Euphemistic
# 767 -- Euphemistic
# 768 -- Euphemistic
# 769 -- Euphemistic
# 770 -- Euphemistic
# 771 -- Euphemistic
# 772 -- Euphemistic
# 773 -- Euphemistic
# 774 -- Euphemistic
# 775 -- Euphemistic
# 776 -- Euphemistic
# 777 -- Euphemistic
# 778 -- Euphemistic
# 779 -- Euphemistic
# 780 -- Euphemistic
# 781 -- Euphemistic
# 782 -- Euphemistic
# 783 -- Euphemistic
# 784 -- Euphemistic
# 785 -- Euphemistic
# 786 -- Euphemistic
# 787 -- Euphemistic
# 788 -- Euphemistic
# 789 -- Euphemistic
# 790 -- Euphemistic
# 791 -- Euphemistic
# 792 -- Euphemistic
# 793 -- Euphemistic
# 794 -- Euphemistic
# 795 -- Euphemistic
# 796 -- Euphemistic
# 797 -- Euphemistic
# 798 -- Euphemistic
# 799 -- Euphemistic
# 800 -- Euphemistic
# 801 -- Euphemistic
# 802 -- Euphemistic
# 803 -- Euphemistic
# 804 -- Euphemistic
# 805 -- Euphemistic
# 806 -- Euphemistic
# 807 -- Euphemistic
# 808 -- Euphemistic
# 809 -- Euphemistic
# 810 -- Euphemistic
# 811 -- Euphemistic
# 812 -- Euphemistic
# 813 -- Euphemistic
# 814 -- Euphemistic
# 815 -- Euphemistic
# 816 -- Euphemistic
# 817 -- Euphemistic
# 818 -- Euphemistic
# 819 -- Euphemistic
# 820 -- Euphemistic
# 821 -- Euphemistic
# 822 -- Euphemistic
# 823 -- Euphemistic
# 824 -- Euphemistic
# 825 -- Euphemistic
# 826 -- Euphemistic
# 827 -- Euphemistic
# 828 -- Euphemistic
# 829 -- Euphemistic
# 830 -- Euphemistic
# 831 -- Euphemistic
# 832 -- Euphemistic
# 833 -- Euphemistic
# 834 -- Non-Euphemistic
# 835 -- Euphemistic
# 836 -- Euphemistic
# 837 -- Euphemistic
# 838 -- Euphemistic
# 839 -- Euphemistic
# 840 -- Euphemistic
# 841 -- Euphemistic
# 842 -- Euphemistic
# 843 -- Euphemistic
# 844 -- Non-Euphemistic
# 845 -- Euphemistic
# 846 -- Euphemistic
# 847 -- Euphemistic
# 848 -- Euphemistic
# 849 -- Euphemistic
# 850 -- Euphemistic
# 851 -- Euphemistic
# 852 -- Euphemistic
# 853 -- Euphemistic
# 854 -- Euphemistic
# 855 -- Euphemistic
# 856 -- Euphemistic
# 857 -- Euphemistic
# 858 -- Euphemistic
# 859 -- Euphemistic
# 860 -- Euphemistic
# 861 -- Euphemistic
# 862 -- Euphemistic
# 863 -- Euphemistic
# 864 -- Euphemistic
# 865 -- Euphemistic
# 866 -- Euphemistic
# 867 -- Euphemistic
# 868 -- Euphemistic
# 869 -- Euphemistic
# 870 -- Euphemistic
# 871 -- Euphemistic
# 872 -- Euphemistic
# 873 -- Euphemistic
# 874 -- Euphemistic
# 875 -- Euphemistic
# 876 -- Euphemistic
# 877 -- Euphemistic
# 878 -- Euphemistic
# 879 -- Euphemistic
# 880 -- Euphemistic
# 881 -- Euphemistic
# 882 -- Euphemistic
# 883 -- Euphemistic
# 884 -- Euphemistic
# 885 -- Euphemistic
# 886 -- Euphemistic
# 887 -- Euphemistic
# 888 -- Euphemistic
# 889 -- Euphemistic
# 890 -- Euphemistic
# 891 -- Euphemistic
# 892 -- Euphemistic
# 893 -- Euphemistic
# 894 -- Euphemistic
# 895 -- Euphemistic
# 896 -- Euphemistic
# 897 -- Euphemistic
# 898 -- Euphemistic
# 899 -- Euphemistic
# 900 -- Euphemistic
# 901 -- Euphemistic
# 902 -- Euphemistic
# 903 -- Euphemistic
# 904 -- Euphemistic
# 905 -- Euphemistic
# 906 -- Euphemistic
# 907 -- Non-Euphemistic
# 908 -- Euphemistic
# 909 -- Euphemistic
# 910 -- Euphemistic
# 911 -- Euphemistic
# 912 -- Euphemistic
# 913 -- Euphemistic
# 914 -- Euphemistic
# 915 -- Euphemistic
# 916 -- Euphemistic
# 917 -- Euphemistic
# 918 -- Euphemistic
# 919 -- Euphemistic
# 920 -- Euphemistic
# 921 -- Euphemistic
# 922 -- Euphemistic
# 923 -- Euphemistic
# 924 -- Euphemistic
# 925 -- Euphemistic
# 926 -- Euphemistic
# 927 -- Euphemistic
# 928 -- Euphemistic
# 929 -- Euphemistic
# 930 -- Euphemistic
# 931 -- Euphemistic
# 932 -- Euphemistic
# 933 -- Euphemistic
# 934 -- Euphemistic
# 935 -- Euphemistic
# 936 -- Euphemistic
# 937 -- Euphemistic
# 938 -- Euphemistic
# 939 -- Euphemistic
# 940 -- Euphemistic
# 941 -- Euphemistic
# 942 -- Euphemistic
# 943 -- Euphemistic
# 944 -- Euphemistic
# 945 -- Euphemistic
# 946 -- Euphemistic
# 947 -- Euphemistic
# 948 -- Euphemistic
# 949 -- Euphemistic
# 950 -- Euphemistic
# 951 -- Euphemistic
# 952 -- Euphemistic
# 953 -- Euphemistic
# 954 -- Euphemistic
# 955 -- Euphemistic
# 956 -- Euphemistic
# 957 -- Euphemistic
# 958 -- Euphemistic
# 959 -- Euphemistic
# 960 -- Euphemistic
# 961 -- Euphemistic
# 962 -- Euphemistic
# 963 -- Euphemistic
# 964 -- Euphemistic
# 965 -- Euphemistic
# 966 -- Euphemistic
# 967 -- Euphemistic
# 968 -- Euphemistic
# 969 -- Euphemistic
# 970 -- Euphemistic
# 971 -- Euphemistic
# 972 -- Euphemistic
# 973 -- Euphemistic
# 974 -- Euphemistic
# 975 -- Euphemistic
# 976 -- Euphemistic
# 977 -- Euphemistic
# 978 -- Euphemistic
# 979 -- Euphemistic
# 980 -- Euphemistic
# 981 -- Euphemistic
# 982 -- Euphemistic
# 983 -- Euphemistic
# 984 -- Euphemistic
# 985 -- Euphemistic
# 986 -- Euphemistic
# 987 -- Euphemistic
# 988 -- Euphemistic
# 989 -- Euphemistic
# 990 -- Euphemistic
# 991 -- Euphemistic
# 992 -- Euphemistic
# 993 -- Euphemistic
# 994 -- Euphemistic
# 995 -- Euphemistic
# 996 -- Euphemistic
# 997 -- Euphemistic
# 998 -- Euphemistic
# 999 -- Euphemistic
# 1000 -- Euphemistic
# 1001 -- Euphemistic
# 1002 -- Euphemistic
# 1003 -- Euphemistic
# 1004 -- Euphemistic
# 1005 -- Euphemistic
# 1006 -- Euphemistic
# 1007 -- Euphemistic
# 1008 -- Euphemistic
# 1009 -- Euphemistic
# 1010 -- Euphemistic
# 1011 -- Euphemistic
# 1012 -- Euphemistic
# 1013 -- Euphemistic
# 1014 -- Euphemistic
# 1015 -- Euphemistic
# 1016 -- Euphemistic
# 1768 -- Euphemistic
# 1769 -- Euphemistic
# 1770 -- Non-Euphemistic
# 1771 -- Euphemistic
# 1772 -- Euphemistic
# 1773 -- Euphemistic
# 1774 -- Euphemistic
# 1775 -- Euphemistic
# 1776 -- Non-Euphemistic
# 1777 -- Euphemistic
# 1778 -- Euphemistic
# 1779 -- Euphemistic
# 1780 -- Euphemistic
# 1781 -- Euphemistic
# 1782 -- Euphemistic
# 1783 -- Euphemistic
# 1784 -- Euphemistic
# 1785 -- Euphemistic
# 1786 -- Euphemistic
# 1787 -- Euphemistic
# 1788 -- Euphemistic
# 1789 -- Euphemistic
# 1790 -- Euphemistic
# 1791 -- Euphemistic
# 1792 -- Euphemistic
# 1793 -- Euphemistic
# 1794 -- Euphemistic
# 1795 -- Euphemistic
# 1796 -- Euphemistic
# 1797 -- Euphemistic
# 1798 -- Euphemistic
# 1799 -- Euphemistic
# 1800 -- Euphemistic
# 1801 -- Euphemistic
# 1802 -- Euphemistic
# 1803 -- Euphemistic
# 1804 -- Euphemistic
# 1805 -- Euphemistic
# 1806 -- Euphemistic
# 1807 -- Euphemistic
# 1808 -- Euphemistic
# 1809 -- Euphemistic
# 1810 -- Euphemistic
# 1811 -- Euphemistic
# 1812 -- Euphemistic
# 1813 -- Euphemistic
# 1814 -- Euphemistic
# 1815 -- Euphemistic
# 1816 -- Euphemistic
# 1817 -- Euphemistic
# 1818 -- Euphemistic
# 1819 -- Euphemistic
# 1820 -- Euphemistic
# 1821 -- Euphemistic
# 1822 -- Euphemistic
# 1823 -- Euphemistic
# 1824 -- Euphemistic
# 1825 -- Euphemistic
# 1826 -- Euphemistic
# 1827 -- Euphemistic
# 1828 -- Euphemistic
# 1829 -- Euphemistic
# 1830 -- Euphemistic
# 1831 -- Euphemistic
# 1832 -- Euphemistic
# 1833 -- Euphemistic
# 1834 -- Euphemistic
# 1835 -- Euphemistic
# 1836 -- Euphemistic
# 1837 -- Euphemistic
# 1838 -- Euphemistic
# 1839 -- Euphemistic
# 1840 -- Euphemistic
# 1841 -- Euphemistic
# 1842 -- Euphemistic
# 1843 -- Euphemistic
# 1844 -- Euphemistic
# 1845 -- Euphemistic
# 1846 -- Euphemistic
# 1847 -- Euphemistic
# 1848 -- Euphemistic
# 1849 -- Euphemistic
# 1850 -- Euphemistic
# 1851 -- Euphemistic
# 1852 -- Euphemistic
# 1853 -- Euphemistic
# 1854 -- Euphemistic
# 1855 -- Euphemistic
# 1856 -- Non-Euphemistic
# 1857 -- Euphemistic
# 1858 -- Euphemistic
# 1859 -- Euphemistic
# 1860 -- Euphemistic

# %%
##for i in range(len)

# %%
## This just saves the model without config and accompanying files, thus complicating inference
## without any merging afterwards (See other file for merging steps and code)

trainer.save_model("./es_euph_classifier_1.0")

# %%
#from huggingface_hub import notebook_login

# %%
#notebook_login()

# %%
### Pushes the classification epochs/training info to hugging face
## May need name editing afterwards

trainer.push_to_hub("HUGGINGFACE_USERNAME/NAME_OF_CLASSIFIER")
